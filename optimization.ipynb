# %% [markdown]
# <a href="https://colab.research.google.com/github/vccheng2001/Apnea-Detection-LSTM/blob/master/optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Building Your Own Optimizers
# Optimizers tie the loss function and model parameters together by updating the model in response to the output of the loss function. In simpler terms, optimizers shape your model into its most accurate possible form by futzing with the weights. In even more simpler terms, optimizers define the way you want your model to be trained.
#
# The selection of optimizers could have dramatic effect on the performance of your model. If you choose a complex optimizer for a simple model, you would be likely to spend much more time in training with barely improved accuracy. And if you choose a naive optimizer for a complicated model, you would probably end up with poor accuracy.
#
# This exercise will cover:
# - *Part 1: Calling existing optimizers provided by tf.keras*
# - *Part 2: Implementing and evaluating your own optimizers*

# %% [markdown]
# ## Part 1: Calling existing optimizers provided by tf.keras
# In this part, we will build up a demo pipeline, demonstrating how to involve optimizers given by `tf.keras` into the training process.

# %% [markdown]
# ## (1a) Setting up the environment
# Just run the following cell to establish the runtime environment. Note that we're using Tensorflow 2.0 for this part of assignment.

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# If running locally, comment out the following try-except block. 
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
from tensorflow.python.ops import math_ops

# %% [markdown]
# ## (1b) Building a baseline model
# In this task, you will create a simple Linear Regression model with a synthetic toy dataset. Mean Squared Error (MSE) will be used as the loss metric.
#
# Note we have set a seed for `tf.random` for auto grading purpose. Please don't change the seed.

# %%
# A toy dataset of points around y = 4 * x_1 + 3 * x_2 + 2
NUM_EXAMPLES = 2000
tf.random.set_seed(10605)   # DON'T CHANGE THIS!
X_train = tf.random.normal([NUM_EXAMPLES, 2])
noise = tf.random.normal([NUM_EXAMPLES, 1])
y_train = tf.matmul(X_train, [[4.], [3.]]) + 2 + noise

# Definition of the Linear Regression model
class Linear(tf.keras.Model):
  def __init__(self):
    super(Linear, self).__init__()
    self.w = tf.Variable([[5., 5.]], name='weight')
    self.b = tf.Variable(10., name='bias')

  # Implementation of Linear Regression
  # TODO: Replace <FILL IN> with appropriate code
  def call(self, inputs):
    """
      Implementation of Linear Regression. This function will use current parameters to predict the labels for inputs

      Note:
          You should try to make use of Tensorflow library to perform related calculation.

      Args:
          inputs (tf.Tensor): The input tensor of this Linear Regression model.

      Returns:
          tf.Tensor: Predicted label
    """

    y_pred = tf.add(tf.matmul(inputs, self.w, transpose_b=True), self.b)
    return y_pred

# MSE loss function
# TODO: Replace <FILL IN> with appropriate code
def loss(y_true, y_pred):
  """
    Calculate MSE loss between the predicted label and the actual label.

    Note:
        You should try to make use of Tensorflow library to perform related calculation.

    Args:
        y_true (tf.Tensor): The actual label.
        y_pred (tf.Tensor): The predicted label.

    Returns:
        tf.Tensor: MSE loss value
  """
  mse_loss = tf.reduce_mean(tf.square(y_true - y_pred),keepdims=True)
  return mse_loss

# %%
# Test for LR_MSE


m, x, y = Linear(), tf.constant([[1.0, 2.0]]), tf.constant([3.0])
assert np.equal(m(x).numpy()[0][0], 25.0), "Wrong implementation of Linear Regression"
assert np.equal(loss(y,m(x)).numpy(), 484.0), "Wrong implementation of MSE loss"

# %% [markdown]
# ## (1c) Applying an existing optimizer
# Next, we will apply an Adam optimizer provided by `tf.keras` to our previously defined Linear Regression model. You can reuse this code snippet to validate your own optimizers.

# %%
model = Linear()
# Standard method to compile a tf.keras.Model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.1), loss=loss)
# Standard method to fit a tf.keras.Model
print(f"X_train shape: {tf.shape(X_train)}")
print(f"y_train shape: {tf.shape(y_train)}")

model.fit(X_train, y_train, batch_size=32, epochs=10)
print(f"model.w shape: {model.w.shape}")
# Out:
# X_train shape: [2000    2]
# y_train shape: [2000    1]
# Epoch 1/10
# 63/63 [==============================] - 0s 777us/step - loss: 46.4401
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 4.6619
# Epoch 3/10
# 63/63 [==============================] - 0s 794us/step - loss: 1.0225
# Epoch 4/10
# 63/63 [==============================] - 0s 735us/step - loss: 1.0149
# Epoch 5/10
# 63/63 [==============================] - 0s 951us/step - loss: 0.9971
# Epoch 6/10
# 63/63 [==============================] - 0s 739us/step - loss: 0.9725
# Epoch 7/10
# 63/63 [==============================] - 0s 726us/step - loss: 0.9351
# Epoch 8/10
# 63/63 [==============================] - 0s 906us/step - loss: 0.9766
# Epoch 9/10
# 63/63 [==============================] - 0s 783us/step - loss: 1.0021
# Epoch 10/10
# 63/63 [==============================] - 0s 786us/step - loss: 0.9755
# model.w shape: (1, 2)

# %% [markdown]
# ## Part 2: Implementing your own optimizers
# In this part, you will implement four different optimizers by yourself! Don't be panic if you're not good at math stuff, we will give you enough instructions and explanations!
#
# Generally, an optimizer class should contain three methods:
# - `__init__`: Initializes required parameters.
# -  `calculate_gradient`: Calculates gradients in the computational graph.
# - `apply_gradient`: Updates parameters of the model.
#
# Some of you may notice that we're not using the "keras-style" to implement our optimizers. Since keras is a high-level encapsulation, its implementation of optimizers is generally too abstract for you to get the mathematical essence. This hacky way can enable you to design your own optimizers in a lower, Tensorflow level.

# %% [markdown]
# ## (2a) Gradient Descent
# Let's start with the simplest Gradient Descent.
#
# For a Linear Regression model with MSE where $\mathbf{y}=w^T\mathbf{X} + b$, the update rules of parameters at the $t$ th epoch are as follows:
#
# $$w^{(t+1)}=w^{(t)}-\alpha \sum_{i=1}^{n} 2 \cdot (h_{w,b}(\mathbf{X}^{(i)}) - \mathbf{y}^{(i)}) \mathbf{X}^{(i)}$$
#
# $$b^{(t+1)}=b^{(t)}-\alpha \sum_{i=1}^{n} 2 \cdot (h_{w,b}(\mathbf{X}^{(i)}) - \mathbf{y}^{(i)}))$$
#
# where $n$ is the size of input dataset.

# %%
# TODO: Replace <FILL IN> with appropriate code
class GD():
  def __init__(self, lr=0.01):
    """Initializes required parameters.

      Args:
          lr (float): Learning rate.
    """
    self.lr = lr 

  def calculate_gradient(self, X, y, model):
      
   
    N = len(X)
    diff = model(X) - y
   
    grads_w = 2/N *  (diff*X)
    grads_b =  2/N * diff

    print("grads_w: ", tf.shape(grads_w))
    print("grads_b: ", tf.shape(grads_b))

    return grads_w, grads_b


  def apply_gradient(self, grads, model):
 
    print('reducegrad0 shape', tf.reduce_sum(grads[0],axis=0,keepdims=True))
    model.w = model.w - self.lr * tf.reduce_sum(grads[0],axis=0,keepdims=True)
    model.b = model.b - self.lr  * tf.reduce_sum(grads[1],axis=0,keepdims=True)

# %%
# Evaluation
model_0 = Linear()
opt_0 = GD()
print(loss(model_0(X_train), y_train).shape)

print("Initial loss: %.3f" % loss(model_0(X_train), y_train))

epochs = 300
for i in range(epochs):
  # Calculate current gradients
  grads = opt_0.calculate_gradient(X_train, y_train, model_0)
  # Use the optimizer to update gradients
  opt_0.apply_gradient(grads, model_0)
  if i % 20 == 0:
    print("Loss at epoch %d: %.3f" % (i, loss(model_0(X_train), y_train)))

print("Final loss: %.3f" % loss(model_0(X_train), y_train))
print("w = %s, b = %s" % (model_0.w.numpy(), model_0.b.numpy()))
# Out:
# (1, 1)
# Initial loss: 68.725
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[2.06868   3.6274102]], shape=(1, 2), dtype=float32)
# Loss at epoch 0: 66.072
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[2.0260062 3.5605822]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.9842119 3.4949636]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.9432728 3.4305403]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.9031719 3.3672943]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.8638998 3.305202 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.8254298 3.2442403]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.7877492 3.1843927]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.7508434 3.1256285]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.7146963 3.0679438]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.6792895 3.011312 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.6446093 2.9557126]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.6106423 2.9011288]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.5773724 2.8475456]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.5447869 2.7949417]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.5128695 2.7432947]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.4816093 2.6925972]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.4509923 2.6428216]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.421001  2.5939572]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.3916281 2.5459907]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.3628597 2.4988992]], shape=(1, 2), dtype=float32)
# Loss at epoch 20: 30.250
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.33468   2.4526699]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.3070837 2.407289 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.2800527 2.3627346]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.253578  2.3190005]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.2276475 2.2760687]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.2022506 2.2339191]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.177376  2.1925435]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.1530133 2.1519258]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.1291513 2.1120584]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.1057817 2.0729187]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.0828916 2.0344946]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.0604745 1.9967811]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.0385169 1.9597566]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[1.0170134 1.9234114]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.9959518 1.887735 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.97532254 1.8527154 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.9551178 1.8183391]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.9353308 1.7845942]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.91595143 1.7514641 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.8969704 1.7189503]], shape=(1, 2), dtype=float32)
# Loss at epoch 40: 14.141
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.87838167 1.6870326 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.8601752 1.655702 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.84234285 1.6249458 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.8248784 1.5947572]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.8077751 1.5651245]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.79102457 1.5360376 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.7746186 1.507487 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.75855064 1.4794587 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.7428129 1.4519522]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.72740287 1.4249476 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.7123074 1.3984425]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.69752455 1.3724289 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.683047 1.346889]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.6688676 1.3218242]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.6549822 1.2972214]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.6413814 1.273071 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.62806284 1.249368  ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.61501867 1.2261033 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.6022435 1.2032646]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.5897322 1.1808507]], shape=(1, 2), dtype=float32)
# Loss at epoch 60: 6.895
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.57747895 1.1588506 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.56547934 1.1372552 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.5537277 1.1160601]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.5422172 1.0952566]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.5309468 1.0748376]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.5199083 1.054795 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.5090977 1.0351236]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.4985104 1.0158169]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.48814088 0.9968665 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.47798768 0.97826755]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.46804404 0.9600117 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.45830545 0.94209313]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.44876873 0.92450804]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.43942943 0.90724754]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.43028203 0.8903079 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.4213243 0.8736814]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.4125523 0.8573616]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.40396163 0.8413452 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.39554816 0.8256271 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.3873104 0.8101985]], shape=(1, 2), dtype=float32)
# Loss at epoch 80: 3.636
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.37924242 0.79505634]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.37134168 0.7801964 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.36360314 0.7656089 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.3560266  0.75129473]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.3486058  0.73724425]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.34133953 0.72345626]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.33422318 0.70992464]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.32725447 0.6966423 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.32043016 0.68360823]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.31374684 0.6708141 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.30720195 0.6582591 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.3007929 0.6459374]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.29451755 0.6338443 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.28837165 0.6219763 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.28235272 0.61032826]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.27645913 0.59889627]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.27068725 0.5876773 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.2650354 0.5766686]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.2595009 0.5658625]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0
], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.02012202 0.0575184 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01969329 0.0564265 ]], shape=(1, 2), dtype=float32)
# Loss at epoch 220: 0.979
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01927357 0.05535502]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01886286 0.05430359]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.0184603  0.05327208]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01806672 0.05226046]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01768127 0.05126769]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01730384 0.05029399]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01693451 0.04933862]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01657322 0.04840158]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01621899 0.04748188]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01587278 0.04657932]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01553368 0.04569399]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01520164 0.04482523]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01487664 0.0439733 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01455867 0.04313758]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01424783 0.0423176 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01394303 0.04151313]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01364524 0.04072397]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01335353 0.03994955]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01306791 0.03918964]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01278838 0.03844421]], shape=(1, 2), dtype=float32)
# Loss at epoch 240: 0.973
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01251481 0.03771313]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01224734 0.03699579]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01198497 0.03629186]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01172857 0.03560144]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01147736 0.03492426]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01123113 0.03425969]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01099005 0.03360763]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01075491 0.03296797]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01052387 0.03234036]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01029791 0.03172493]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.01007701 0.03112092]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00986114 0.03052866]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00964934 0.02994771]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00944256 0.02937763]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00923983 0.02881833]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00904123 0.02826945]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00884664 0.02773087]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00865616 0.0272028 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00846972 0.02668465]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00828732 0.02617653]], shape=(1, 2), dtype=float32)
# Loss at epoch 260: 0.971
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00810898 0.02567779]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00793466 0.02518857]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00776436 0.02470901]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00759717 0.02423839]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00743394 0.0237763 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00727382 0.02332334]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00711682 0.022879  ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00696381 0.0224428 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00681385 0.02201516]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00666694 0.02159569]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00652309 0.02118384]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00638224 0.02077977]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00624454 0.02038342]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00610985 0.01999464]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00597816 0.01961319]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00584946 0.01923899]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00572292 0.01887211]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.0055994  0.01851191]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00547889 0.01815904]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00536043 0.01781251]], shape=(1, 2), dtype=float32)
# Loss at epoch 280: 0.970
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.005245   0.01747275]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00513169 0.01713932]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00502038 0.01681228]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00491213 0.0164916 ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00480592 0.01617671]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00470177 0.01586775]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00459967 0.01556469]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00450051 0.01526759]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00440348 0.01497641]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00430836 0.01469053]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00421539 0.01441032]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00412448 0.01413533]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00403552 0.01386536]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00394773 0.01360041]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00386195 0.01334088]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00377819 0.01308596]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00369643 0.01283596]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00361579 0.012591  ]], shape=(1, 2), dtype=float32)
# grads_w:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# grads_b:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# reducegrad0 shape tf.Tensor([[0.00353714 0.01235058]], shape=(1, 2), dtype=float32)
# Final loss: 0.969
# w = [[4.0046396 3.0552888]], b = [[2.0367746]]

# %%
# Test case
assert np.allclose(loss(model_0(X_train), y_train), 0.969, atol=1e-3), 'Wrong implementation of GD'

# %% [markdown]
# ## (2b) Stochastic Gradient Descent
# Let's take one step further. In SGD, you should randomly choose one data point to calculate the gradient each time.

# %%
# TODO: Replace <FILL IN> with appropriate code
class SGD():
  def __init__(self, lr=0.01):
    """Initializes required parameters.

      Args:
          lr (float): Learning rate.
    """
    # self.lr = <FILL IN>

    self.lr = lr 

  def calculate_gradient(self, X, y, model):
    """Calculates gradients in the computational graph.

      Note:
          You should try to make use of Tensorflow library to perform related calculation.

      Args:
          X (tf.Tensor): The input.
          y (tf.Tensor): The actual label.
          model (tf.keras.Model): The model used to predict y with given input X. 

      Returns:
          Tuple: (gradient w.r.t w, gradient w.r.t b)
    """
    import random 

    N = len(y)
    # randomly choose a training example i
    i = random.randint(0, N-1)
    xi = tf.expand_dims(X[i,:], axis=0)
    yi = y[i,:]

    diff = tf.subtract(model(xi), yi)
    # print('diff shape', diff.shape)
    # print('xi shape', xi.shape) # diff:11, xi:  12 -> 12
    # print('w shape', model.w.shape)
    grads_w =  2 * (tf.matmul(diff, xi, transpose_a=True))
    grads_b =  2 * (diff)
    return (grads_w, grads_b)

  def apply_gradient(self, grads, model):
    """Updates parameters of the model.

      Note:
          You should try to make use of Tensorflow library to perform related calculation.

      Args:
          grads (Tuple): (gradient w.r.t W, gradient w.r.t B).
          model (tf.keras.Model): The model used to predict y with given input X. 
    """
    model.w = model.w - self.lr * grads[0]
    model.b = model.b - self.lr * grads[1]

# %%
# Evaluation
model_1 = Linear()
opt_1 = SGD()

print("Initial loss: %.3f" % loss(model_1(X_train), y_train))

epochs = 300
for i in range(epochs):
  # Calculate current gradients
  grads = opt_1.calculate_gradient(X_train, y_train, model_1)
  # Use the optimizer to update gradients
  opt_1.apply_gradient(grads, model_1)
  if i % 20 == 0:
    print("Loss at epoch %d: %.3f" % (i, loss(model_1(X_train), y_train)))

print("Final loss: %.3f" % loss(model_1(X_train), y_train))
print("w = %s, b = %s" % (model_1.w.numpy(), model_1.b.numpy()))
# Out:
# Initial loss: 68.725
# Loss at epoch 0: 65.545
# Loss at epoch 20: 34.270
# Loss at epoch 40: 15.212
# Loss at epoch 60: 6.076
# Loss at epoch 80: 3.472
# Loss at epoch 100: 2.323
# Loss at epoch 120: 1.638
# Loss at epoch 140: 1.312
# Loss at epoch 160: 1.169
# Loss at epoch 180: 1.169
# Loss at epoch 200: 1.091
# Loss at epoch 220: 1.021
# Loss at epoch 240: 1.070
# Loss at epoch 260: 1.071
# Loss at epoch 280: 0.985
# Final loss: 0.995
# w = [[4.0214953 3.0479925]], b = [[2.1778488]]

# %%
# Test case
assert np.allclose(loss(model_1(X_train), y_train), 1.0, atol=0.05), 'Wrong implementation of SGD'

# %% [markdown]
# ## (2c) AdaGrad
#
# One of the shortcomings about Gradient Descent is that its performance highly depends on the initial learning rate. Poor selection of initial learning rate would lead to either slow convergence or incapability of finding local minimum. In order to solve this problem, a revised version called AdaGrad is introduced.
#
# As its name suggests, AdaGrad makes its learning rate adaptive. To be more specific, AdaGrad uses past squared gradients to form an accumulated regularizer for its learning rate.
#
# Assuming $g^{(t)}$ is the gradient at $t$ th epoch, AdaGrad first calculates the accumulated squared gradients:
#
# $$r^{(t)}=r^{(t-1)}+(g^{(t)})^2$$
#
# Then AdaGrad will use this accumulated squared gradients to regularize its learning rate:
#
# $$w^{(t+1)}=w^{(t)}-\frac{\alpha}{\sqrt{r^{(t)}} + \epsilon} \cdot g_w^{(t)}$$
# $$b^{(t+1)}=b^{(t)}-\frac{\alpha}{\sqrt{r^{(t)}} + \epsilon} \cdot g_b^{(t)}$$
#
# where $\epsilon$ is an additive constant (usually set as $10^{-7}$) that ensures we do not divide by 0.
#
# Note that you can reuse the `calculate_gradient` function in SGD for AdaGrad.

# %%
class AdaGrad():
  def __init__(self, lr=0.001, epsilon=1e-7):
    """Initializes required parameters.

      Note: self.accumulator is the accumulated squared gradients. It is a tuple with following format:
        (accumulator w.r.t w, accumulator w.r.t b)
        And it should be initialized with the value of 0.1

      Args:
          lr (float): Learning rate.
          epsilon (float): Additive constant that ensures we do not divide by 0.
    """
    self.lr = lr
    self.epsilon = epsilon
    self.accumulator = (0.1, 0.1)

    
  def calculate_gradient(self, X, y, model):
    """Calculates gradients in the computational graph.

      Note:
          You should try to make use of Tensorflow library to perform related calculation.

      Args:
          X (tf.Tensor): The input.
          y (tf.Tensor): The actual label.
          model (tf.keras.Model): The model used to predict y with given input X. 

      Returns:
          Tuple: (gradient w.r.t w, gradient w.r.t b)
    """
    N = len(X)

    diff = tf.subtract(model(X), y)
    grads_w =  tf.reduce_sum(2/N * (diff*X))
    grads_b =  tf.reduce_sum(2/N * (diff))
    print('calculated grads_w', tf.shape(grads_w))
    print('calculated grads_b', tf.shape(grads_b))

    print('end calc')
    return (grads_w, grads_b)
    


  def apply_gradient(self, grads, model):
    """Updates parameters of the model.

      Note:
          You should try to make use of Tensorflow library to perform related calculation.

      Args:
          grads (Tuple): (gradient w.r.t w, gradient w.r.t b).
          model (tf.keras.Model): The model used to predict y with given input X. 
    """
    
    self.accumulator =  (self.accumulator[0] + tf.square(grads[0]), self.accumulator[1] + tf.square(grads[1])) 

    r = self.accumulator
    model.w = model.w - (self.lr / (np.sqrt(r[0]) + self.epsilon)) * grads[0]
    model.b = model.b - (self.lr / (np.sqrt(r[1]) + self.epsilon)) * grads[1]
    print('grads0', tf.shape(grads[0]))
    print('grads0squ', tf.shape(tf.square(grads[0])))


    print("end apply")
    print('self.accum', self.accumulator)

# %%
# Evaluation
model_2 = Linear()
opt_2 = AdaGrad(lr=0.1)

print("Initial loss: %.3f" % loss(model_2(X_train), y_train))

epochs = 300
for i in range(epochs):
  # Calculate current gradients
  grads = opt_2.calculate_gradient(X_train, y_train, model_2)
  # Use the optimizer to update gradients
  opt_2.apply_gradient(grads, model_2)
  if i % 20 == 0:
    print("Loss at epoch %d: %.3f" % (i, loss(model_2(X_train), y_train)))

print("Final loss: %.3f" % loss(model_2(X_train), y_train))
print("w = %s, b = %s" % (model_2.w.numpy(), model_2.b.numpy()))
# Out:
# Initial loss: 68.725
# calculated grads_w tf.Tensor([], shape=(0,), dtype=int32)
# calculated grads_b tf.Tensor([], shape=(0,), dtype=int32)
# end calc
# grads0 tf.Tensor([], shape=(0,), dtype=int32)
# grads0squ tf.Tensor([], shape=(0,), dtype=int32)
# end apply
# self.accum (<tf.Tensor: shape=(), dtype=float32, numpy=32.54546>, <tf.Tensor: shape=(), dtype=float32, numpy=250.69766>)
# Loss at epoch 0: 66.604
# calculated grads_w tf.Tensor([], shape=(0,), dtype=int32)
# calculated grads_b tf.Tensor([], shape=(0,), dtype=int32)
# end calc
# grads0 tf.Tensor([], shape=(0,), dtype=int32)
# grads0squ tf.Tensor([], shape=(0,), dtype=int32)
# end apply
# self.accum (<tf.Tensor: shape=(), dtype=float32, numpy=60.50036>, <tf.Tensor: shape=(), dtype=float32, numpy=495.21298>)
# calculated grads_w tf.Tensor([], shape=(0,), dtype=int32)
# calculated grads_b tf.Tensor([], shape=(0,), dtype=int32)
# end calc
# grads0 tf.Tensor([], shape=(0,), dtype=int32)
# grads0squ tf.Tensor([], shape=(0,), dtype=int32)
# end apply
# self.accum (<tf.Tensor: shape=(), dtype=float32, numpy=85.590866>, <tf.Tensor: shape=(), dtype=float32, numpy=735.4937>)
# calculated grads_w tf.Tensor([], shape=(0,), dtype=int32)
# calculated grads_b tf.Tensor([], shape=(0,), dtype=int32)
# end calc
# grads0 tf.Tensor([], shape=(0,), dtype=int32)
# grads0squ tf.Tensor([], shape=(0,), dtype=int32)
# end apply
# self.accum (<tf.Tensor: shape=(), dtype=float32, numpy=108.51137>, <tf.Tensor: shape=(), dtype=float32, numpy=972.35486>)
# calculated grads_w tf.Tensor([], shape=(0,), dtype=int32)
# calculated grads_b tf.Tensor([], shape=(0,), dtype=int32)
# end calc
# grads0 tf.Tensor([], shape=(0,), dtype=int32)
# grads0squ tf.Tensor([], shape=(0,), dtype=int32)
# end apply
# self.accum (<tf.Tensor: shape=(), dtype=float32, numpy=129.66736>, <tf.Tensor: shape=(), dtype=float32, numpy=1206.2812>)
# calculated grads_w tf.Tensor([], shape=(0,), dtype=int32)
# calculated grads_b tf.Tensor([], shape=(0,), dtype=int32)
# end calc
# grads0 tf.Tensor([], shape=(0,), dtype=int32)
# grads0squ tf.Tensor([], shape=(0,), dtype=int32)
# end apply
# self.accum (<tf.Tensor: shape=(), dtype=float32, numpy=149.3313>, <tf.Tensor: shape=(), dtype=float32, numpy=1437.6034>)
# calculated grads_w tf.Tensor([], shape=(0,), dtype=int32)
# calculated grads_b tf.Tensor([], shape=(0,), dtype=int32)
# end calc
# grads0 tf.Tensor([], shape=(0,), dtype=int32)
# grads0squ tf.Tensor([], shape=(0,), dtype=int32)
# end apply
# self.accum (<tf.Tensor: shape=(), dtype=float32, numpy=167.70166>, <tf.Tensor: shape=(), dtype=float32, numpy=1666.565>)
# calculated grads_w tf.Tensor([], shape=(0,), dtype=int32)
# calculated grads_b tf.Tensor([], shape=(0,), dtype=int32)
# end calc
# grads0 tf.Tensor([], shape=(0,), dtype=int32)
# grads0squ tf.Tensor([], shape=(0,), dtype=int32)
# end apply
# self.accum (<tf.Tensor: shape=(), dtype=float32, numpy=184.9308>, <tf.Tensor: shape=(), dtype=float32, numpy=1893.3551>)
# calculated grads_w tf.Tensor([], shape=(0,), dtype=int32)
# calculated grads_b tf.Tensor([], shape=(0,), dtype=int32)
# end calc
# grads0 tf.Tensor([], shape=(0,), dtype=int32)
# grads0squ tf.Tensor([], shape=(0,), dtype=int32)
# end apply
# self.accum (<tf.Tensor: shape=(), dtype=float32, numpy=201.14017>, <tf.Tensor: shape=(), dtype=float32, numpy=2118.1265>)
# calculated grads_w tf.Tensor([], shape=(0,), dtype=int32)
# calculated grads_b tf.Tensor([], shape=(0,), dtype=int32)
# end calc
# grads0 tf.Tensor([], shape=(0,), dtype=int32)
# grads0squ tf.Tensor([], shape=(0,), dtype=int32)
# end apply
# self.accum (<tf.Tensor: shape=(), dtype=float32, numpy=216.4292>, <tf.Tensor: shape=(), dtype=float32, numpy=2341.0051>)
# calculated grads_w tf.Tensor([], shape=(0,), dtype=int32)
# calculated grads_b tf.Tensor([], shape=(0,), dtype=int32)
# end calc
# grads0 tf.Tensor([], shape=(0,), dtype=int32)
# grads0squ tf.Tensor([], shape=(0,), dtype=int32)
# end apply
# self.accum (<tf.Tensor: shape=(), dtype=float32, numpy=230.88113>, <tf.Tensor: shape=(), dtype=float32, numpy=2562.0977>)
# calculated grads_w tf.Tensor([], shape=(0,), dtype=int32)
# calculated grads_b tf.Tensor([], shape=(0,), dtype=int32)
# end calc
# grads0 tf.Tensor([], shape=(0,), dtype=int32)
# grads0squ tf.Tensor([], shape=(0,), dtype=int32)
# end apply
# self.accum (<tf.Tensor: shape=(), dtype=float32, numpy=244.56679>, <tf.Tensor: shape=(), dtype=float32, numpy=2781.496>)
# calculated grads_w tf.Tensor([], shape=(0,), dtype=int32)
# calculated grads_b tf.Tensor([], shape=(0,), dtype=int32)
# end calc
# grads0 tf.Tensor([], shape=(0,), dtype=int32)
# grads0squ tf.Tensor([], shape=(0,), dtype=int32)
# end apply
# self.accum (<tf.Tensor: shape=(), dtype=float32, numpy=257.54724>, <tf.Tensor: shape=(), dtype=float32, numpy=2999.2803>)
# calculated grads_w tf.Tensor([], shape=(0,), dtype=int32)
# calculated grads_b tf.Tensor([], shape=(0,), dtype=int32)
# end calc
# grads0 tf.Tensor([], shape=(0,), dtype=int32)
# grads0squ tf.Tensor([], shape=(0,), dtype=int32)
# end apply
# self.accum (<tf.Tensor: shape=(), dtype=float32, numpy=269.87585>, <tf.Tensor: shape=(), dtype=float32, numpy=3215.5208>)
# calculated grads_w tf.Tensor([], shape=(0,), dtype=int32)
# calculated grads_b tf.Tensor([], shape=(0,), dtype=int32)
# end calc
# grads0 tf.Tensor([], shape=(0,), dtype=int32)
# grads0squ tf.Tensor([], shape=(0,), dtype=int32)
# end apply
# self.accum (<tf.Tensor: shape=(), dtype=float32, numpy=281.5996>, <tf.Tensor: shape=(), dtype=float32, numpy=3430.2805>)
# calculated grads_w tf.Tensor([], shape=(0,), dtype=int32)
# calculated grads_b tf.Tensor([], shape=(0,), dtype=int32)
# end calc
# grads0 tf.Tensor([], shape=(0,), dtype=int32)
# grads0squ tf.Tensor([], shape=(0,), dtype=int32)
# end apply
# self.accum (<tf.Tensor: shape=(), dtype=float32, numpy=292.76022>, <tf.Tensor: shape=(), dtype=float32, numpy=3643.616>)
# calculated grads_w tf.Tensor([], shape=(0,), dtype=int32)
# calculated grads_b tf.Tensor([], shape=(0,), dtype=int32)
# end calc
# grads0 tf.Tensor([], shape=(0,), dtype=int32)
# grads0squ tf.Tensor([], shape=(0,), dtype=int32)
# end apply
# self.accum (<tf.Tensor: shape=(), dtype=float32, numpy
)
# calculated grads_w tf.Tensor([], shape=(0,), dtype=int32)
# calculated grads_b tf.Tensor([], shape=(0,), dtype=int32)
# end calc
# grads0 tf.Tensor([], shape=(0,), dtype=int32)
# grads0squ tf.Tensor([], shape=(0,), dtype=int32)
# end apply
# self.accum (<tf.Tensor: shape=(), dtype=float32, numpy=565.1146>, <tf.Tensor: shape=(), dtype=float32, numpy=42658.01>)
# calculated grads_w tf.Tensor([], shape=(0,), dtype=int32)
# calculated grads_b tf.Tensor([], shape=(0,), dtype=int32)
# end calc
# grads0 tf.Tensor([], shape=(0,), dtype=int32)
# grads0squ tf.Tensor([], shape=(0,), dtype=int32)
# end apply
# self.accum (<tf.Tensor: shape=(), dtype=float32, numpy=565.1163>, <tf.Tensor: shape=(), dtype=float32, numpy=42754.973>)
# Final loss: 25.628
# w = [[3.592024 3.592024]], b = 6.9565134

# %%
# Test case
assert np.allclose(loss(model_2(X_train), y_train), 29.0, atol=2.0), 'Wrong implementation of AdaGrad'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-141-f020be421104> in <module>()
#       1 # Test case
# ----> 2 assert np.allclose(loss(model_2(X_train), y_train), 29.0, atol=2.0), 'Wrong implementation of AdaGrad'
#
# AssertionError: Wrong implementation of AdaGrad

# %% [markdown]
# ## (2d) Adam
# Although it sounds like a powerful algorithm, AdaGrad still has a bunch of shortcomings. One of them is that as the accumulated squared gradients becoming larger, the learning rate will be pushed to 0, leading to an early stop.
#
# Adam is designed to improve AdaGrad. It relies on adaptive moment estimation to set an independent adaptive learning rate for each parameter. The idea of Adam at the $t$ th epoch is described below:
# - Calculate current gradient $g^{(t)}$
# - Update biased first moment estimate
#   $$m^{(t)} = \beta_1\cdot m^{(t-1)}+(1-\beta_1)\cdot g^{(t)}$$
# - Update biased second raw moment estimate
#   $$v^{(t)} = \beta_2\cdot v^{(t-1)}+(1-\beta_2)\cdot (g^{(t)})^2$$
# - Compute bias-corrected first moment estimate
#   $$\hat{m}^{(t)} = \frac{m^{(t)}}{1-\beta_1^t}$$
# - Compute bias-corrected second raw moment estimate
#   $$\hat{v}^{(t)} = \frac{v^{(t)}}{1-\beta_2^t}$$
# - Update parameters with constrained learning rate
#   $$w^{(t)} = w^{(t-1)}-\alpha\cdot\frac{\hat{m}_w^{(t)}}{(\sqrt{\hat{v}_w^{(t)}}+\epsilon)}$$
#   $$b^{(t)} = b^{(t-1)}-\alpha\cdot\frac{\hat{m}_b^{(t)}}{(\sqrt{\hat{v}_b^{(t)}}+\epsilon)}$$
#
# where $\beta_1$ and $\beta_2$ are hyperparameters for the first and the second moment estimation
#
# As we can see from the update rule, Adam dynamically forms boundaries for its learning rate using first and second moment estimate without requiring too much memory space.
#
# Note that you can reuse the `calculate_gradient` function in SGD for Adam.

# %%
# TODO: Replace <FILL IN> with appropriate code
class Adam():
  def __init__(self, lr=0.001, beta1=0.9, beta2=0.999, epsilon=1e-7):
    """Initializes required parameters.

      Note: 
        self.m is a list of Tensor, representing first moment estimations of gradients. The initial value should be [0]. 
        self.v is a list of Tensor, representing second moment estimations of gradients. The initial value should be [0]. 
        self.t is the timestep. The initial value should be 0. 

      Args:
          lr (float): Learning rate.
          epsilon (float): Additive constant that ensures we do not divide by 0.
          beta1 (float): Hyperparameter for first moment estimation
          beta2 (float): Hyperparameter for second moment estimation
    """
    self.lr = lr
    self.beta1 = beta1
    self.beta2 = beta2
    self.epsilon = epsilon
    self.v = [0]
    self.m = [0]
    self.t = 0
    
    
  def calculate_gradient(self, X, y, model):
    """Calculates gradients in the computational graph.

      Note:
          You should try to make use of Tensorflow library to perform related calculation.

      Args:
          X (tf.Tensor): The input.
          y (tf.Tensor): The actual label.
          model (tf.keras.Model): The model used to predict y with given input X. 

      Returns:
          Tuple: (gradient w.r.t w, gradient w.r.t b)
    """

    N = len(X)

    diff = tf.subtract(model(X), y)
    grads_w =  2/N * tf.reduce_sum(tf.matmul(diff, X, transpose_a=True))
    grads_b =  2/N * tf.reduce_sum(diff)
    return (grads_w, grads_b)
    

  def apply_gradient(self, grads, model):
    """Updates parameters of the model.

      Note:
          You should try to make use of Tensorflow library to perform related calculation.

      Args:
          grads (Tuple): (gradient w.r.t w, gradient w.r.t b).
          model (tf.keras.Model): The model used to predict y with given input X. 
    """
    # biased first moment estimate 
    self.m = tf.multiply(self.beta1, self.m) + tf.multiply((1-self.beta1), grads)
    self.v = tf.multiply(self.beta2, self.v) + tf.multiply((1-self.beta2), tf.square(grads))

    print("m", tf.shape(self.m))
    print("v", tf.shape(self.v))

    # normalize
    self.m = self.m / (1-self.beta1)
    self.v = self.v / (1-self.beta2)

    # update weights 
    model.w = model.w - self.lr * (self.m / (tf.sqrt(self.v) + self.epsilon))
    model.b = model.b - self.lr * (self.m / (tf.sqrt(self.v) + self.epsilon))

# %%
# Evaluation
model_3 = Linear()
opt_3 = Adam(lr=0.1)
print("Initial loss: %.3f" % loss(model_3(X_train), y_train))

epochs = 300
for i in range(epochs):
  # Calculate current gradients
  grads = opt_3.calculate_gradient(X_train, y_train, model_3)
  # Use the optimizer to update gradients
  opt_3.apply_gradient(grads, model_3)
  if i % 20 == 0:
    print("Loss at epoch %d: %.3f" % (i, loss(model_3(X_train), y_train)))

print("Final loss: %.3f" % loss(model_3(X_train), y_train))
print("w = %s, b = %s" % (model_3.w.numpy(), model_3.b.numpy()))
# Out:
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# b:  tf.Tensor([], shape=(0,), dtype=int32)
# Initial loss: 68.725
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    1], shape=(2,), dtype=int32)
# b:  tf.Tensor([], shape=(0,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# Loss at epoch 0: 66.603
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# Loss at epoch 20: 65.595
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# Loss at epoch 40: nan
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# Loss at epoch 60: nan
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# Loss at epoch 80: nan
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# Loss at epoch 100: nan
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# Loss at epoch 120: nan
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# Loss at epoch 140: nan
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# Loss at epoch 160: nan
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# m tf.Tensor([2], shape=(1,), dtype=int32)
# v tf.Tensor([2], shape=(1,), dtype=int32)
# w:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# x:  tf.Tensor([1 2], shape=(2,), dtype=int32)
# y:  tf.Tensor([2000    2], shape=(2,), dtype=int32)
# b:  tf.Tensor([2], shape=(1,), dtype=int32)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-215-072584c402e4> in <module>()
#       9   grads = opt_3.calculate_gradient(X_train, y_train, model_3)
#      10   # Use the optimizer to update gradients
# ---> 11   opt_3.apply_gradient(grads, model_3)
#      12   if i % 20 == 0:
#      13     print("Loss at epoch %d: %.3f" % (i, loss(model_3(X_train), y_train)))
#
# <ipython-input-214-fd873fa9a99a> in apply_gradient(self, grads, model)
#      59     # biased first moment estimate
#      60     self.m = tf.multiply(self.beta1, self.m) + tf.multiply((1-self.beta1), grads)
# ---> 61     self.v = tf.multiply(self.beta2, self.v) + tf.multiply((1-self.beta2), tf.square(grads))
#      62
#      63     print("m", tf.shape(self.m))
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_ops.py in multiply(x, y, name)
#     516   """
#     517
# --> 518   return gen_math_ops.mul(x, y, name)
#     519
#     520
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_math_ops.py in mul(x, y, name)
#    6063     try:
#    6064       _result = pywrap_tfe.TFE_Py_FastPathExecute(
# -> 6065         _ctx, "Mul", name, x, y)
#    6066       return _result
#    6067     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Test case
assert np.allclose(loss(model_3(X_train), y_train), 1.0, atol=0.4), 'Wrong implementation of Adam'
